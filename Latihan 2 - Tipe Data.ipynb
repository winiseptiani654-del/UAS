# %% [markdown]
# # UAS Politeknik Krakatau

# %% [markdown]
# - Nama:
# - Kelas :
# - Dosen Pengampu : Yudistira Dwi Permana

# %% [markdown]
# ### Data Primitif

# %%
# isilah kode di bawah ini
x = '123'
print('x')
print(type(x))

# agar menghasilkan output: <class 'str'>
# Out:
# x
# <class 'str'>

# %% [markdown]
# penjelasan

# %%
# Betulkan kode di bawah sehingga menghasilkan output True
x = {1, 2, None}

print(None in x)
# Out:
# True

# %% [markdown]
# penjelasan

# %%
# Menuliskan Variable Dengan multi Line
multiline ="""Halo!
Kapan terakhir kita bertemu?
Kita bertemu hari Rabu yang lalu."""

print(multiline)
# Out:
# Halo!
# Kapan terakhir kita bertemu?
# Kita bertemu hari Rabu yang lalu.

# %% [markdown]
# penjelasan

# %%
# Indexing pada String
x = 'Yudis'

# tuliskan agar menghasilkan output 'd'
print(x[2])
# tuliskan agar menghasilkan output 'Yis'
print(x[0]+x[3:])
# Out:
# d
# Yis

# %% [markdown]
# penjelasan
