# %% [markdown]
# # UAS Politeknik Krakatau

# %% [markdown]
# - Nama:
# - Kelas :
# - Dosen Pengampu : Yudistira Dwi Permana

# %% [markdown]
# ### Variable Dan Assignment

# %%
# lengkapi kode di bawah ini
 = ''
print('halo nama saya ' + <variable>)

# agar menjadi output halo nama saya <isi nama kamu>

# %% [markdown]
# penjelasan
